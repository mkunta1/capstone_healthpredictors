# %%
import pandas as pd
providers1 = pd.read_csv('C:\\Users\\Mahi2\\capstone\\capstone_healthpredictors\\data\\providers.csv')
# View a few rows (table)
print(providers1.head().to_string())
# Out:
#                                      Id                          ORGANIZATION                   NAME GENDER        SPECIALITY                  ADDRESS        CITY STATE    ZIP        LAT        LON  UTILIZATION
# 0  c795d2dd-42d6-31c8-8bc0-ffe8d7f600cc  ef58ea08-d883-3957-8300-150554edc8fb      Barry322 Moore224      M  GENERAL PRACTICE         60 HOSPITAL ROAD  LEOMINSTER    MA  01453  42.520838 -71.770876        16963
# 1  e747102c-e7ac-3c2a-824d-83698ea7cc2c  69176529-fd1f-3b3f-abce-a0a3626769eb  Lyndsey828 Schultz619      F  GENERAL PRACTICE  330 MOUNT AUBURN STREET   CAMBRIDGE    MA  02138  42.375967 -71.118275        28517
# 2  fb558fe2-f4ce-39c0-8a4a-1f5e84300113  5e765f2b-e908-3888-9fc7-df2cb87beb58  Leontine92 Lebsack687      F  GENERAL PRACTICE          211 PARK STREET   ATTLEBORO    MA  02703  41.931653 -71.294503        23074
# 3  70aca2db-5180-39a4-abe0-2c5eaffaf74d  f1fbcbfb-fcfa-3bd2-b7f4-df20f1b3c3a4        Lee268 Robel940      M  GENERAL PRACTICE       ONE GENERAL STREET    LAWRENCE    MA  01842  42.700273 -71.161357        20593
# 4  046c4fac-2680-391a-ba36-eeaec6eed0c5  e002090d-4e92-300e-b41e-7d1f21dee4c6    Min362 Bergstrom287      F  GENERAL PRACTICE    1493 CAMBRIDGE STREET   CAMBRIDGE    MA  02138  42.375967 -71.118275        31316

# %%
print("\nShape (rows, columns):", providers1.shape)
print(providers1.columns.tolist())
# Out:
# Shape (rows, columns): (31764, 12)
# ['Id', 'ORGANIZATION', 'NAME', 'GENDER', 'SPECIALITY', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'LAT', 'LON', 'UTILIZATION']

# %%
print(providers1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31764 entries, 0 to 31763
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            31764 non-null  object
#  1   ORGANIZATION  31764 non-null  object
#  2   NAME          31764 non-null  object
#  3   GENDER        31764 non-null  object
#  4   SPECIALITY    31764 non-null  object
#  5   ADDRESS       31764 non-null  object
#  6   CITY          31764 non-null  object
#  7   STATE         31764 non-null  object
#  8   ZIP           31764 non-null  object
#  9   LAT           31764 non-null  float64
#  10  LON           31764 non-null  float64
#  11  UTILIZATION   31764 non-null  int64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 2.9+ MB
# None

# %%
providers1['memberid'] = providers1['Id'].str[:8]
# Check the result
print(providers1.head().to_string())
# Out:
#                                      Id                          ORGANIZATION                   NAME GENDER        SPECIALITY                  ADDRESS        CITY STATE    ZIP        LAT        LON  UTILIZATION  memberid
# 0  c795d2dd-42d6-31c8-8bc0-ffe8d7f600cc  ef58ea08-d883-3957-8300-150554edc8fb      Barry322 Moore224      M  GENERAL PRACTICE         60 HOSPITAL ROAD  LEOMINSTER    MA  01453  42.520838 -71.770876        16963  c795d2dd
# 1  e747102c-e7ac-3c2a-824d-83698ea7cc2c  69176529-fd1f-3b3f-abce-a0a3626769eb  Lyndsey828 Schultz619      F  GENERAL PRACTICE  330 MOUNT AUBURN STREET   CAMBRIDGE    MA  02138  42.375967 -71.118275        28517  e747102c
# 2  fb558fe2-f4ce-39c0-8a4a-1f5e84300113  5e765f2b-e908-3888-9fc7-df2cb87beb58  Leontine92 Lebsack687      F  GENERAL PRACTICE          211 PARK STREET   ATTLEBORO    MA  02703  41.931653 -71.294503        23074  fb558fe2
# 3  70aca2db-5180-39a4-abe0-2c5eaffaf74d  f1fbcbfb-fcfa-3bd2-b7f4-df20f1b3c3a4        Lee268 Robel940      M  GENERAL PRACTICE       ONE GENERAL STREET    LAWRENCE    MA  01842  42.700273 -71.161357        20593  70aca2db
# 4  046c4fac-2680-391a-ba36-eeaec6eed0c5  e002090d-4e92-300e-b41e-7d1f21dee4c6    Min362 Bergstrom287      F  GENERAL PRACTICE    1493 CAMBRIDGE STREET   CAMBRIDGE    MA  02138  42.375967 -71.118275        31316  046c4fac

# %%
providers1['memberid'] = providers1['Id'].str[:8]
# Check the result
print(providers1.head().to_string())

unique_memberids = providers1['memberid'].nunique()
print(unique_memberids)
# Out:
#                                      Id                          ORGANIZATION                   NAME GENDER        SPECIALITY                  ADDRESS        CITY STATE    ZIP        LAT        LON  UTILIZATION  memberid
# 0  c795d2dd-42d6-31c8-8bc0-ffe8d7f600cc  ef58ea08-d883-3957-8300-150554edc8fb      Barry322 Moore224      M  GENERAL PRACTICE         60 HOSPITAL ROAD  LEOMINSTER    MA  01453  42.520838 -71.770876        16963  c795d2dd
# 1  e747102c-e7ac-3c2a-824d-83698ea7cc2c  69176529-fd1f-3b3f-abce-a0a3626769eb  Lyndsey828 Schultz619      F  GENERAL PRACTICE  330 MOUNT AUBURN STREET   CAMBRIDGE    MA  02138  42.375967 -71.118275        28517  e747102c
# 2  fb558fe2-f4ce-39c0-8a4a-1f5e84300113  5e765f2b-e908-3888-9fc7-df2cb87beb58  Leontine92 Lebsack687      F  GENERAL PRACTICE          211 PARK STREET   ATTLEBORO    MA  02703  41.931653 -71.294503        23074  fb558fe2
# 3  70aca2db-5180-39a4-abe0-2c5eaffaf74d  f1fbcbfb-fcfa-3bd2-b7f4-df20f1b3c3a4        Lee268 Robel940      M  GENERAL PRACTICE       ONE GENERAL STREET    LAWRENCE    MA  01842  42.700273 -71.161357        20593  70aca2db
# 4  046c4fac-2680-391a-ba36-eeaec6eed0c5  e002090d-4e92-300e-b41e-7d1f21dee4c6    Min362 Bergstrom287      F  GENERAL PRACTICE    1493 CAMBRIDGE STREET   CAMBRIDGE    MA  02138  42.375967 -71.118275        31316  046c4fac
# 31764

# %%
# Now join them in pandas
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Now join them in pandas
# ----> 2 joined = pd.merge(patients1, providers1, on='memberid', how='inner')
#       3 print(joined)
#
# NameError: name 'patients1' is not defined
